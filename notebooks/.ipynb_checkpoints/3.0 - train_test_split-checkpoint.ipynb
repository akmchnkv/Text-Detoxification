# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/interim/filtered_df.tsv', sep='\t')
df.head()
# Out:
#                                            reference  \
# 0               real life starts first time fuck kid
# 1                       hey leave poor bastard alone
# 2                            told waste fucking time
# 3  swear god best thing ever life save little son...
# 4                                          dont shit
#
#                                          translation  similarity  length_diff  \
# 0                         boy real life starts first    0.866697     0.319149
# 1                               leave poor man alone    0.857554     0.257143
# 2                                    told waste time    0.904062     0.183673
# 3  swear god best thing ive ever done life save l...    0.932305     0.022472
# 4                                      dont anything    0.806763     0.137931
#
#     ref_tox   trn_tox  reference_length  translation_length  \
# 0  0.998222  0.000114                 9                   6
# 1  0.999382  0.000578                 6                   5
# 2  0.995877  0.000479                11                  10
# 3  0.999071  0.000900                21                  19
# 4  0.995474  0.000047                 6                   6
#
#                                         common_words  common_words_count  \
# 0                         {'life', 'starts', 'real'}                   3
# 1                 {'leave', 'the', 'alone!', 'poor'}                   4
# 2  {'was', 'time.', 'a', 'told', 'waste', 'of', '...                   9
# 3  {'the', 'was', 'life', 'best', 'ever', 'swear'...                  14
# 4                 {"don't", 'to', 'have', 'i', 'do'}                   5
#
#    reference_stopwords  translation_stopwords  reference_sentiment  \
# 0                    2                      1             0.016667
# 1                    1                      1            -0.500000
# 2                    7                      7            -0.400000
# 3                   11                      8             0.406250
# 4                    5                      5            -0.200000
#
#    translation_sentiment
# 0                0.22500
# 1               -0.50000
# 2               -0.20000
# 3                0.40625
# 4                0.00000

# %%
train_df, temp = train_test_split(df, train_size=0.7, random_state=42)
val_df, test_df = train_test_split(temp, train_size=0.1, random_state=42)

# %%
train_df.shape, val_df.shape, test_df.shape
# Out:
# ((25033, 14), (1072, 14), (9657, 14))

# %%
train_df.to_csv("../data/interim/train_df")
val_df.to_csv("../data/interim/val_df")
test_df.to_csv("../data/interim/test_df")
